# %%
# read file
import json
f = open("recipe.txt", "r")
data = json.load(f)
print(len(data))
# Out:
# 574

# %%
# print ingredients list
ingredients = []
for i in range(574):
    ingredients.append(data[i]['strIngredient1'])
    ingredients.append(data[i]['strIngredient2'])
    ingredients.append(data[i]['strIngredient3'])
    ingredients.append(data[i]['strIngredient4'])
    ingredients.append(data[i]['strIngredient5'])
    ingredients.append(data[i]['strIngredient6'])
    ingredients.append(data[i]['strIngredient7'])
                        
print(ingredients)
    

    # print(list1)
    

    # final_list = list1+list2
    # print(final_list)

    
    # filtered_list = list(filter(None, final_list))
            

    
    # list = obj[i]['strIngredient1'] + obj[i]['strIngredient2'] + obj[i]['strIngredient3']
    
    
    # list = list1 + list2 + list3 + list4 + list5 + list6 + list7
    # list = [*list1, *list2, *list3, *list4, *list5, *list6, *list7]
    # print(list)
# Out:
# ['Light rum', 'Lime', 'Sugar', 'Mint', 'Soda water', None, None, 'Bourbon', 'Angostura bitters', 'Sugar', 'Water', None, None, None, 'Vodka', 'Light rum', 'Gin', 'Tequila', 'Lemon', 'Coca-Cola', None, 'Gin', 'Campari', 'Sweet Vermouth', None, None, None, None, 'Blended whiskey', 'Lemon', 'Powdered sugar', 'Cherry', 'Lemon', None, None, 'Gin', 'Dry Vermouth', 'Olive', None, None, None, None, 'Light rum', 'Lime', 'Powdered sugar', None, None, None, None, 'Tequila', 'Triple sec', 'Lime juice', 'Salt', None, None, None, 'Sweet Vermouth', 'Bourbon', 'Angostura bitters', 'Ice', 'Maraschino cherry', 'Orange peel', None, 'Vodka', 'Lime juice', 'Ginger ale', None, None, None, None, 'Apricot brandy', 'Triple sec', 'Lime', 'Lime', None, None, None, 'Triple sec', 'Apricot brandy', 'Lemon juice', None, None, None, None, 'Southern Comfort', 'Amaretto', 'Sloe gin', 'Lemon juice', None, None, None, 'Orange bitters', 'Gin', 'Yellow Chartreuse', 'Lemon peel', None, None, None, 'Gin', 'Creme de Cacao',
# ...

# %%
instruction = []
for i in range(574):
    instruction.append(data[i]['strInstructions'])        
#     instruction = instruction.strip("\r\n")              
# print(instruction)
instruction = " ".join(instruction)
instruction.strip("\r\n")
print(instruction)
# Out:
# Muddle mint leaves with sugar and lime juice. Add a splash of soda water and fill the glass with cracked ice. Pour the rum and top with soda water. Garnish and serve with straw. Place sugar cube in old fashioned glass and saturate with bitters, add a dash of plain water. Muddle until dissolved.
# Fill the glass with ice cubes and add whiskey.
#
# ...
